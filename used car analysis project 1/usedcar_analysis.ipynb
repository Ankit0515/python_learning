# %%
# First we will import our data set but before that lets import important libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
import plotly.express as px
import plotly.graph_objs as go

# %%
#Importing dataset

used_cars = pd.read_csv(r"E:\python_learning\used car analysis project 1\UserCarData.csv")

# %%
used_cars.head()
# Out:
#    Sales_ID     name  year  selling_price  km_driven   Region  \
# 0         1   Maruti  2014         450000     145500     East
# 1         2    Skoda  2014         370000     120000     East
# 2         3    Honda  2006         158000     140000  Central
# 3         4  Hyundai  2010         225000     127000  Central
# 4         5   Maruti  2007         130000     120000     East
#
#       State or Province           City    fuel seller_type transmission  \
# 0  District of Columbia     Washington  Diesel  Individual       Manual
# 1              New York  New York City  Diesel  Individual       Manual
# 2              Illinois        Chicago  Petrol  Individual       Manual
# 3              Illinois        Chicago  Diesel  Individual       Manual
# 4              New York  New York City  Petrol  Individual       Manual
#
#           owner  mileage  engine  max_power                    torque  seats  \
# 0   First_Owner    23.40    1248      74.00            190Nm@ 2000rpm      5
# 1  Second_Owner    21.14    1498     103.52       250Nm@ 1500-2500rpm      5
# 2   Third_Owner    17.70    1497      78.00     12.7@ 2,700(kgm@ rpm)      5
# 3   First_Owner    23.00    1396      90.00  22.4 kgm at 1750-2750rpm      5
# 4   First_Owner    16.10    1298      88.20     11.5@ 4,500(kgm@ rpm)      5
#
#   sold
# 0    Y
# 1    Y
# 2    Y
# 3    Y
# 4    Y

# %%
# Cars who have been sold most

figsize=(15,5)
brands = used_cars.sort_values(by = "name",ascending= False)
sns.catplot(y = "name",data = brands, kind = "count" , height = 7, aspect=1.5,palette= "plasma")
plt.title("No.of Vehicles sold",fontdict= {'size':20})
plt.xlabel("Vehicle count",fontdict= {'size':15})
plt.ylabel("Car Brands",fontdict= {'size':15})
plt.xticks(rotation = 90)
plt.show()

# %%
# Avg selling price according to Car Brands

from turtle import color

sp_avg = used_cars.groupby("name")["selling_price"].mean().plot(kind = "bar",figsize=(15,5),color = "palevioletred")
plt.title("Avg. Selling Price",fontdict= {'size':20})
plt.xlabel("Type Of Vehicle",fontdict= {'size':15})
plt.ylabel("Selling Price",fontdict= {'size':15})
plt.xticks(rotation = 90)
plt.show()

# %%
# Sales of vechiles on year basis 

fig, ax = plt.subplots(figsize=(15,5))
# sp = sns.(y = "year", data = used_cars)
sp = sns.histplot(used_cars["year"], color="#33cc33",kde=True ,ax=ax)
ax.set_title('Distribution of vehicles based on Year ', fontsize= 15)
plt.ylabel("Count", fontsize= 15)
plt.xlabel("Years", fontsize= 15)
plt.show()

# %%
import plotly.io as pio

# %%
# Percentage of Manual and Automatic cars 

px.pie(used_cars,values = 'km_driven',names='transmission')

# %%
# Kilometer driven by car brand with respect to Transmission_type

fig, ax = plt.subplots(figsize=(15,5))
sns.lineplot(data = used_cars, x = 'name', y = 'km_driven', hue = 'transmission')
plt.xticks(rotation = 90)
ax.set_title('Manual and Automatic Car kilometer driven ', fontsize= 15)
plt.show()

# %%
#  Graph 1 - Relationship between maxx power and engine 
#  Graph 2 - Relationship between maxx power and engine with respect to Mileage


fig, ax = plt.subplots(figsize=(15,10))

plt.subplot(2,1,1)
sns.scatterplot(data = used_cars, x = "engine", y = "max_power", palette='pink_r')
plt.xticks(rotation = 90)

fig, ax = plt.subplots(figsize=(15,10))
plt.subplot(2,1,2)
sns.scatterplot(data = used_cars, x = "engine", y = "max_power",hue ="mileage" , palette='icefire')
plt.xticks(rotation = 90)

plt.show()

# %%
# Count of fuel type

sns.countplot(data = used_cars, x = 'fuel', palette= 'gist_earth')
# Out:
# <AxesSubplot:xlabel='fuel', ylabel='count'>

# %%
# Kilometer driven using various types of fuel
# Count of fuel type of various brands

fig, ax = plt.subplots(figsize=(15,10))
plt.subplot(2,1,1)
sns.pointplot(x = 'fuel',y = 'km_driven', data = used_cars, kind = 'hist', color= 'red')

plt.subplot(2,1,2)

sns.countplot(data = used_cars, x = 'name', hue = 'fuel', palette = 'hls' )
plt.xticks(rotation = 90)




plt.show()

# %%
# Selling price with respect to fuel type of various brands 

sns.barplot( data = used_cars, x = 'name', y = 'selling_price', hue = 'fuel', palette='rocket')
plt.xticks(rotation = 90)
plt.show()

# %%
# relationship b/w maximum power and engine cc with respect to selling price

px.scatter(used_cars, x = 'engine', y = "max_power",color = 'selling_price')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\Somya Shrivastava\miniconda3\envs\myenv\lib\site-packages\IPython\core\formatters.py:921, in IPythonDisplayFormatter.__call__(self, obj)
#     919 method = get_real_method(obj, self.print_method)
#     920 if method is not None:
# --> 921     method()
#     922     return True
#
# File c:\Users\Somya Shrivastava\miniconda3\envs\myenv\lib\site-packages\plotly\basedatatypes.py:842, in BaseFigure._ipython_display_(self)
#     839 import plotly.io as pio
#     841 if pio.renderers.render_on_display and pio.renderers.default:
# --> 842     pio.show(self)
#     843 else:
#     844     print(repr(self))
#
# File c:\Users\Somya Shrivastava\miniconda3\envs\myenv\lib\site-packages\plotly\io\_renderers.py:396, in show(fig, renderer, validate, **kwargs)
#     391         raise ValueError(
#     392             "Mime type rendering requires ipython but it is not installed"
#     393         )
#     395     if not nbformat or LooseVersion(nbformat.__version__) < LooseVersion("4.2.0"):
# --> 396         raise ValueError(
#     397             "Mime type rendering requires nbformat>=4.2.0 but it is not installed"
#     398         )
#     400     ipython_display.display(bundle, raw=True)
#     402 # external renderers
#
# ValueError: Mime type rendering requires nbformat>=4.2.0 but it is not installed
# Figure({
#     'data': [{'hovertemplate': 'engine=%{x}<br>max_power=%{y}<br>selling_price=%{marker.color}<extra></extra>',
#               'legendgroup': '',
#               'marker': {'color': array([450000, 370000, 158000, ..., 382000, 290000, 290000], dtype=int64),
#                          'coloraxis': 'coloraxis',
#                          'symbol': 'circle'},
#               'mode': 'markers',
#               'name': '',
#               'showlegend': False,
#               'type': 'scattergl',
#               'x': array([1248, 1498, 1497, ..., 1248, 1396, 1396], dtype=int64),
#               'xaxis': 'x',
#               'y': array([ 74.  , 103.52,  78.  , ...,  73.9 ,  70.  ,  70.  ]),
#               'yaxis': 'y'}],
#     'layout': {'coloraxis': {'colorbar': {'title': {'text': 'selling_price'}},
#                              'colorscale': [[0.0, '#0d0887'], [0.1111111111111111,
#                                             '#46039f'], [0.2222222222222222,
#                                             '#7201a8'], [0.3333333333333333,
#                                             '#9c179e'], [0.4444444444444444,
#                                             '#bd3786'], [0.5555555555555556,
#                                             '#d8576b'], [0.6666666666666666,
#                                             '#ed7953'], [0.7777777777777778,
#                                             '#fb9f3a'], [0.8888888888888888,
#                                             '#fdca26'], [1.0, '#f0f921']]},
#                'legend': {'tracegroupgap': 0},
#                'margin': {'t': 60},
#                'template': '...',
#                'xaxis': {'anchor': 'y', 'domain': [0.0, 1.0], 'title': {'text': 'engine'}},
#                'yaxis': {'anchor': 'x', 'domain': [0.0, 1.0], 'title': {'text': 'max_power'}}}
# })

# %% [markdown]
# # Manual and Automatic cars of different brands
#
# fig, ax = plt.subplots(figsize=(15,8))
# sns.countplot(data = used_cars, x = 'brand_name',hue = 'transmission_type',palette= 'magma')
# plt.xticks(rotation = 90)
# plt.title('Distribution of Manual and Automatic cars',fontsize = 15)

# %%
# #  Difference b/w original price and selling price of Each brand's Avg price

# avg = used_cars.groupby('brand_name', as_index=False).mean()
# fig = go.Figure()
# fig.add_trace(go.Scatter( x = avg['brand_name'], y = avg['original_price'], name="Org Price"))
# fig.add_trace(go.Bar( x = avg['brand_name'], y = avg['SP'], name = 'Sell price'))
# fig.update_layout(title_text='Difference b/w Original price and Selling price ',  plot_bgcolor='wheat', height = 800)

# %%
sns.pairplot(used_cars.select_dtypes(include=['int']))
